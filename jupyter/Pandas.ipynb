# %% [markdown]
# # Series

# %%
import pandas as pd
import numpy as np

series_test = pd.Series([100, 200, 300])

series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({1999: 48,
                          2000: 65,
                          2001: 89})

series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %% [markdown]
# # DataFrame

# %%
frame_test = pd.DataFrame({1999: [74, 38, 39],
                           2000: [10, 84, 13],
                           2001: [58, 97, 164]})
frame_test
# Out:
#    1999  2000  2001
# 0    74    10    58
# 1    38    84    97
# 2    39    13   164

# %%
frame_test2 = pd.DataFrame([[74, 38, 39],
                           [10, 84, 13],
                           [58, 97, 164]])

frame_test2
# Out:
#     0   1    2
# 0  74  38   39
# 1  10  84   13
# 2  58  97  164

# %% [markdown]
# # Read data

# %%
pd.options.display.max_rows = 10

semana = pd.read_csv('../web_scrapper/semana_2019_11_06_articles.csv')

type(semana)

semana
# Out:
#                                                  body  \
# 0   Este martes en la noche se cumpli el sorteo de...
# 1   "Con este nivel de juego es difcil que nos d p...
# 2   Un experimento con resultados no esperados. As...
# 3   Durante el programa Vicky en Semana, de la per...
# 4   Poco a poco se conocen detalles de la estremec...
# ..                                                ...
# 39  La iluminacin de calles o la recoleccin de bas...
# 40  El nombre de Margarita Rosa de Francisco est g...
# 41  En el Congreso volvi a aterrizar una iniciativ...
# 42  Ayer en la maana, en los pasillos del Congreso...
# 43  James Rodrguez est viviendo momentos difciles ...
#
#                                                 title  \
# 0   La nueva pelcula de 'Terminator', un fracaso d...
# 1   Por qu James pasa por su peor momento desde su...
# 2   Sony yMicrosoftse unen para desarrollar videoj...
# 3   As estn las cuentas en el Congreso para sacar ...
# 4   La nueva pelcula de 'Terminator', un fracaso d...
# ..                                                ...
# 39                      Educacin y Premios Nobel 2019
# 40  Escribo para no ignorarme para tenerme ms en c...
# 41  Llmelo como quiera: Corte Constitucional acaba...
# 42  "Bombardeo contra campamento de Gildardo Cucho...
# 43  "No es de Shannon": las revelaciones sobre el ...
#
#                                                   url
# 0   https://www.semana.com//deportes/articulo/asi-...
# 1   https://www.semana.com//deportes/articulo/cham...
# 2   https://www.semana.com//vida-moderna/articulo/...
# 3   https://www.semana.com//nacion/articulo/roy-ba...
# 4   https://www.semana.com//mundo/articulo/el-acto...
# ..                                                ...
# 39  https://www.dinero.com/pais/articulo/como-se-i...
# 40  https://www.semana.com//gente/articulo/margari...
# 41  https://www.semana.com//nacion/articulo/radica...
# 42  https://www.semana.com//nacion/articulo/mocion...
# 43  https://www.semana.com//deportes/articulo/por-...
#
# [44 rows x 3 columns]

# %% [markdown]
# # Index and selection

# %%
# dictionary like

semana['title']
# Out:
# 0     La nueva pelcula de 'Terminator', un fracaso d...
# 1     Por qu James pasa por su peor momento desde su...
# 2     Sony yMicrosoftse unen para desarrollar videoj...
# 3     As estn las cuentas en el Congreso para sacar ...
# 4     La nueva pelcula de 'Terminator', un fracaso d...
#                             ...
# 39                        Educacin y Premios Nobel 2019
# 40    Escribo para no ignorarme para tenerme ms en c...
# 41    Llmelo como quiera: Corte Constitucional acaba...
# 42    "Bombardeo contra campamento de Gildardo Cucho...
# 43    "No es de Shannon": las revelaciones sobre el ...
# Name: title, Length: 44, dtype: object

# %%
semana[['title', 'url']]
# Out:
#                                                 title  \
# 0   La nueva pelcula de 'Terminator', un fracaso d...
# 1   Por qu James pasa por su peor momento desde su...
# 2   Sony yMicrosoftse unen para desarrollar videoj...
# 3   As estn las cuentas en el Congreso para sacar ...
# 4   La nueva pelcula de 'Terminator', un fracaso d...
# ..                                                ...
# 39                      Educacin y Premios Nobel 2019
# 40  Escribo para no ignorarme para tenerme ms en c...
# 41  Llmelo como quiera: Corte Constitucional acaba...
# 42  "Bombardeo contra campamento de Gildardo Cucho...
# 43  "No es de Shannon": las revelaciones sobre el ...
#
#                                                   url
# 0   https://www.semana.com//deportes/articulo/asi-...
# 1   https://www.semana.com//deportes/articulo/cham...
# 2   https://www.semana.com//vida-moderna/articulo/...
# 3   https://www.semana.com//nacion/articulo/roy-ba...
# 4   https://www.semana.com//mundo/articulo/el-acto...
# ..                                                ...
# 39  https://www.dinero.com/pais/articulo/como-se-i...
# 40  https://www.semana.com//gente/articulo/margari...
# 41  https://www.semana.com//nacion/articulo/radica...
# 42  https://www.semana.com//nacion/articulo/mocion...
# 43  https://www.semana.com//deportes/articulo/por-...
#
# [44 rows x 2 columns]

# %%
# Numpy like

semana.iloc[10:15]
# Out:
#                                                  body  \
# 10  Cuando era una niala cineasta chilena Lissette...
# 11  Durante el debate de control poltico que se ll...
# 12  Mientras el presidente Ivn Duque sala de un ev...
# 13  "Declaramos de forma clara e inequvoca que el ...
# 14  Tres turistas mexicanos y una suiza resultaron...
#
#                                                 title  \
# 10  Este es un Gobierno cmplice de la dictadura: M...
# 11  La nueva pelcula de 'Terminator', un fracaso d...
# 12  La cadena de errores que termin con la renunci...
# 13  La nueva pelcula de 'Terminator', un fracaso d...
# 14         Un siglo de consecuencias en Oriente Medio
#
#                                                   url
# 10  https://www.semana.com//mundo/articulo/lissett...
# 11  https://www.semana.com//nacion/articulo/dario-...
# 12  https://www.semana.com//nacion/articulo/de-que...
# 13  https://www.semana.com//vida-moderna/articulo/...
# 14  https://www.semana.com//mundo/articulo/conmoci...

# %%
semana.iloc[12]['title']
# Out:
# 'La cadena de errores que termin con la renuncia del ministro Botero'

# %%
semana.iloc[:5, 0]
# Out:
# 0    Este martes en la noche se cumpli el sorteo de...
# 1    "Con este nivel de juego es difcil que nos d p...
# 2    Un experimento con resultados no esperados. As...
# 3    Durante el programa Vicky en Semana, de la per...
# 4    Poco a poco se conocen detalles de la estremec...
# Name: body, dtype: object

# %%
semana.loc[:, 'body': 'title']
# Out:
#                                                  body  \
# 0   Este martes en la noche se cumpli el sorteo de...
# 1   "Con este nivel de juego es difcil que nos d p...
# 2   Un experimento con resultados no esperados. As...
# 3   Durante el programa Vicky en Semana, de la per...
# 4   Poco a poco se conocen detalles de la estremec...
# ..                                                ...
# 39  La iluminacin de calles o la recoleccin de bas...
# 40  El nombre de Margarita Rosa de Francisco est g...
# 41  En el Congreso volvi a aterrizar una iniciativ...
# 42  Ayer en la maana, en los pasillos del Congreso...
# 43  James Rodrguez est viviendo momentos difciles ...
#
#                                                 title
# 0   La nueva pelcula de 'Terminator', un fracaso d...
# 1   Por qu James pasa por su peor momento desde su...
# 2   Sony yMicrosoftse unen para desarrollar videoj...
# 3   As estn las cuentas en el Congreso para sacar ...
# 4   La nueva pelcula de 'Terminator', un fracaso d...
# ..                                                ...
# 39                      Educacin y Premios Nobel 2019
# 40  Escribo para no ignorarme para tenerme ms en c...
# 41  Llmelo como quiera: Corte Constitucional acaba...
# 42  "Bombardeo contra campamento de Gildardo Cucho...
# 43  "No es de Shannon": las revelaciones sobre el ...
#
# [44 rows x 2 columns]

# %% [markdown]
# # Data wrangling

# %%
# 1. añadir newspaper_uid al DataFrame

semana['newspaper_uid'] = 'semana'

semana
# Out:
#                                                  body  \
# 0   Este martes en la noche se cumpli el sorteo de...
# 1   "Con este nivel de juego es difcil que nos d p...
# 2   Un experimento con resultados no esperados. As...
# 3   Durante el programa Vicky en Semana, de la per...
# 4   Poco a poco se conocen detalles de la estremec...
# ..                                                ...
# 39  La iluminacin de calles o la recoleccin de bas...
# 40  El nombre de Margarita Rosa de Francisco est g...
# 41  En el Congreso volvi a aterrizar una iniciativ...
# 42  Ayer en la maana, en los pasillos del Congreso...
# 43  James Rodrguez est viviendo momentos difciles ...
#
#                                                 title  \
# 0   La nueva pelcula de 'Terminator', un fracaso d...
# 1   Por qu James pasa por su peor momento desde su...
# 2   Sony yMicrosoftse unen para desarrollar videoj...
# 3   As estn las cuentas en el Congreso para sacar ...
# 4   La nueva pelcula de 'Terminator', un fracaso d...
# ..                                                ...
# 39                      Educacin y Premios Nobel 2019
# 40  Escribo para no ignorarme para tenerme ms en c...
# 41  Llmelo como quiera: Corte Constitucional acaba...
# 42  "Bombardeo contra campamento de Gildardo Cucho...
# 43  "No es de Shannon": las revelaciones sobre el ...
#
#                                                   url newspaper_uid
# 0   https://www.semana.com//deportes/articulo/asi-...        semana
# 1   https://www.semana.com//deportes/articulo/cham...        semana
# 2   https://www.semana.com//vida-moderna/articulo/...        semana
# 3   https://www.semana.com//nacion/articulo/roy-ba...        semana
# 4   https://www.semana.com//mundo/articulo/el-acto...        semana
# ..                                                ...           ...
# 39  https://www.dinero.com/pais/articulo/como-se-i...        semana
# 40  https://www.semana.com//gente/articulo/margari...        semana
# 41  https://www.semana.com//nacion/articulo/radica...        semana
# 42  https://www.semana.com//nacion/articulo/mocion...        semana
# 43  https://www.semana.com//deportes/articulo/por-...        semana
#
# [44 rows x 4 columns]

# %%
# 2. obtener el host

from urllib.parse import urlparse

semana['host'] = semana['url'].apply(lambda url: urlparse(url).netloc)

semana
# Out:
#                                                  body  \
# 0   Este martes en la noche se cumpli el sorteo de...
# 1   "Con este nivel de juego es difcil que nos d p...
# 2   Un experimento con resultados no esperados. As...
# 3   Durante el programa Vicky en Semana, de la per...
# 4   Poco a poco se conocen detalles de la estremec...
# ..                                                ...
# 39  La iluminacin de calles o la recoleccin de bas...
# 40  El nombre de Margarita Rosa de Francisco est g...
# 41  En el Congreso volvi a aterrizar una iniciativ...
# 42  Ayer en la maana, en los pasillos del Congreso...
# 43  James Rodrguez est viviendo momentos difciles ...
#
#                                                 title  \
# 0   La nueva pelcula de 'Terminator', un fracaso d...
# 1   Por qu James pasa por su peor momento desde su...
# 2   Sony yMicrosoftse unen para desarrollar videoj...
# 3   As estn las cuentas en el Congreso para sacar ...
# 4   La nueva pelcula de 'Terminator', un fracaso d...
# ..                                                ...
# 39                      Educacin y Premios Nobel 2019
# 40  Escribo para no ignorarme para tenerme ms en c...
# 41  Llmelo como quiera: Corte Constitucional acaba...
# 42  "Bombardeo contra campamento de Gildardo Cucho...
# 43  "No es de Shannon": las revelaciones sobre el ...
#
#                                                   url newspaper_uid  \
# 0   https://www.semana.com//deportes/articulo/asi-...        semana
# 1   https://www.semana.com//deportes/articulo/cham...        semana
# 2   https://www.semana.com//vida-moderna/articulo/...        semana
# 3   https://www.semana.com//nacion/articulo/roy-ba...        semana
# 4   https://www.semana.com//mundo/articulo/el-acto...        semana
# ..                                                ...           ...
# 39  https://www.dinero.com/pais/articulo/como-se-i...        semana
# 40  https://www.semana.com//gente/articulo/margari...        semana
# 41  https://www.semana.com//nacion/articulo/radica...        semana
# 42  https://www.semana.com//nacion/articulo/mocion...        semana
# 43  https://www.semana.com//deportes/articulo/por-...        semana
#
#               host
# 0   www.semana.com
# 1   www.semana.com
# 2   www.semana.com
# 3   www.semana.com
# 4   www.semana.com
# ..             ...
# 39  www.dinero.com
# 40  www.semana.com
# 41  www.semana.com
# 42  www.semana.com
# 43  www.semana.com
#
# [44 rows x 5 columns]

# %%
semana['host'].value_counts()
# Out:
# www.semana.com            36
# www.revistaarcadia.com     5
# www.dinero.com             3
# Name: host, dtype: int64

# %% [markdown]
# ## Missing Data

# %%
# Simulate missing data
semana['title'][5] = np.NaN
semana['title'][18] = np.NaN
semana['title'][33] = np.NaN
semana['title'][40] = np.NaN

# %%
# 3. Rellenar datos faltantes
missing_titles_mask = semana['title'].isna()

#semana[missing_titles_mask]['url']
missing_titles = (semana[missing_titles_mask]['url']
                    .str
                    .extract(r'(?P<missing_titles>[^/]+)/[^/]+$')
                    .applymap(lambda title: title.split('-'))
                    .applymap(lambda title_word_list: ' '.join(title_word_list))
                )
missing_titles
# Out:
#                                        missing_titles
# 5   fotografia para el fin del mundo episodio xi  ...
# 18  renuncia del ministro botero los errores que l...
# 33  la dura respuesta de shannon de lima tras crit...
# 40  margarita rosa de francisco a veces siento ver...

# %% [markdown]
# ## Additional cleanup

# %%
# 4. añadir uid a las filas
import hashlib

uids = (semana
            .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
            .apply(lambda hash_object: hash_object.hexdigest())
        )

semana['uid'] = uids
semana.set_index('uid', inplace=True)

semana
# Out:
#                                                                                body  \
# uid
# 7da415dea9662ea9a86bb9511a97d018  Este martes en la noche se cumpli el sorteo de...
# cf95bed3ca9731c52344be47f1c47828  "Con este nivel de juego es difcil que nos d p...
# 12101d7231ebe08b10c9960e43dc1d6f  Un experimento con resultados no esperados. As...
# d1863696880af5764bb079c76eb5328c  Durante el programa Vicky en Semana, de la per...
# a77b77e72c58bf6c4fb0ab16de9b4439  Poco a poco se conocen detalles de la estremec...
# ...                                                                             ...
# 0ac9dc5c1780ddb3720ed0b220bc03cc  La iluminacin de calles o la recoleccin de bas...
# b82d7a219f809ba37ea242d6cbb3ae3c  El nombre de Margarita Rosa de Francisco est g...
# 886e3e2c9db0b56f45183e5e1cfe64f3  En el Congreso volvi a aterrizar una iniciativ...
# 23b6232a093b0c11e25e9eaab73de2c9  Ayer en la maana, en los pasillos del Congreso...
# d1f33e8ba9d5ce1a1160cc6704fcc77b  James Rodrguez est viviendo momentos difciles ...
#
#                                                                               title  \
# uid
# 7da415dea9662ea9a86bb9511a97d018  La nueva pelcula de 'Terminator', un fracaso d...
# cf95bed3ca9731c52344be47f1c47828  Por qu James pasa por su peor momento desde su...
# 12101d7231ebe08b10c9960e43dc1d6f  Sony yMicrosoftse unen para desarrollar videoj...
# d1863696880af5764bb079c76eb5328c  As estn las cuentas en el Congreso para sacar ...
# a77b77e72c58bf6c4fb0ab16de9b4439  La nueva pelcula de 'Terminator', un fracaso d...
# ...                                                                             ...
# 0ac9dc5c1780ddb3720ed0b220bc03cc                      Educacin y Premios Nobel 2019
# b82d7a219f809ba37ea242d6cbb3ae3c                                                NaN
# 886e3e2c9db0b56f45183e5e1cfe64f3  Llmelo como quiera: Corte Constitucional acaba...
# 23b6232a093b0c11e25e9eaab73de2c9  "Bombardeo contra campamento de Gildardo Cucho...
# d1f33e8ba9d5ce1a1160cc6704fcc77b  "No es de Shannon": las revelaciones sobre el ...
#
#                                                                                 url  \
# uid
# 7da415dea9662ea9a86bb9511a97d018  https://www.semana.com//deportes/articulo/asi-...
# cf95bed3ca9731c52344be47f1c47828  https://www.semana.com//deportes/articulo/cham...
# 12101d7231ebe08b10c9960e43dc1d6f  https://www.semana.com//vida-moderna/articulo/...
# d1863696880af5764bb079c76eb5328c  https://www.semana.com//nacion/articulo/roy-ba...
# a77b77e72c58bf6c4fb0ab16de9b4439  https://www.semana.com//mundo/articulo/el-acto...
# ...                                                                             ...
# 0ac9dc5c1780ddb3720ed0b220bc03cc  https://www.dinero.com/pais/articulo/como-se-i...
# b82d7a219f809ba37ea242d6cbb3ae3c  https://www.semana.com//gente/articulo/margari...
# 886e3e2c9db0b56f45183e5e1cfe64f3  https://www.semana.com//nacion/articulo/radica...
# 23b6232a093b0c11e25e9eaab73de2c9  https://www.semana.com//nacion/articulo/mocion...
# d1f33e8ba9d5ce1a1160cc6704fcc77b  https://www.semana.com//deportes/articulo/por-...
#
#                                  newspaper_uid            host
# uid
# 7da415dea9662ea9a86bb9511a97d018        semana  www.semana.com
# cf95bed3ca9731c52344be47f1c47828        semana  www.semana.com
# 12101d7231ebe08b10c9960e43dc1d6f        semana  www.semana.com
# d1863696880af5764bb079c76eb5328c        semana  www.semana.com
# a77b77e72c58bf6c4fb0ab16de9b4439        semana  www.semana.com
# ...                                        ...             ...
# 0ac9dc5c1780ddb3720ed0b220bc03cc        semana  www.dinero.com
# b82d7a219f809ba37ea242d6cbb3ae3c        semana  www.semana.com
# 886e3e2c9db0b56f45183e5e1cfe64f3        semana  www.semana.com
# 23b6232a093b0c11e25e9eaab73de2c9        semana  www.semana.com
# d1f33e8ba9d5ce1a1160cc6704fcc77b        semana  www.semana.com
#
# [44 rows x 5 columns]

# %%
stripped_body = (semana
                     .apply(lambda row: row['body'], axis=1)
                     .apply(lambda body: list(body))
                     .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ''), letters)))
                     .apply(lambda letters: ''.join(letters))
                )

stripped_body
# Out:
# uid
# 7da415dea9662ea9a86bb9511a97d018    Este martes en la noche se cumpli el sorteo de...
# cf95bed3ca9731c52344be47f1c47828    "Con este nivel de juego es difcil que nos d p...
# 12101d7231ebe08b10c9960e43dc1d6f    Un experimento con resultados no esperados. As...
# d1863696880af5764bb079c76eb5328c    Durante el programa Vicky en Semana, de la per...
# a77b77e72c58bf6c4fb0ab16de9b4439    Poco a poco se conocen detalles de la estremec...
#                                                           ...
# 0ac9dc5c1780ddb3720ed0b220bc03cc    La iluminacin de calles o la recoleccin de bas...
# b82d7a219f809ba37ea242d6cbb3ae3c    El nombre de Margarita Rosa de Francisco est g...
# 886e3e2c9db0b56f45183e5e1cfe64f3    En el Congreso volvi a aterrizar una iniciativ...
# 23b6232a093b0c11e25e9eaab73de2c9    Ayer en la maana, en los pasillos del Congreso...
# d1f33e8ba9d5ce1a1160cc6704fcc77b    James Rodrguez est viviendo momentos difciles ...
# Length: 44, dtype: object

# %% [markdown]
# ## Data Enrichment

# %%
# 6. tokenizar el titulo y el body
import nltk
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\julengyel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\julengyel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('spanish'))

def tokenize_column(df, column_name):
    return (df
                .dropna() # delete invalid data
                .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
                .apply(lambda tokens: list(filter(lambda token: token.isalpha(), tokens)))
                .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
                .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
                .apply(lambda valid_word_list: len(valid_word_list))
            )

semana['n_tokens_title'] = tokenize_column(semana, 'title')
semana['n_tokens_body'] = tokenize_column(semana, 'body')

semana
# Out:
#                                                                                body  \
# uid
# 7da415dea9662ea9a86bb9511a97d018  Este martes en la noche se cumpli el sorteo de...
# cf95bed3ca9731c52344be47f1c47828  "Con este nivel de juego es difcil que nos d p...
# 12101d7231ebe08b10c9960e43dc1d6f  Un experimento con resultados no esperados. As...
# d1863696880af5764bb079c76eb5328c  Durante el programa Vicky en Semana, de la per...
# a77b77e72c58bf6c4fb0ab16de9b4439  Poco a poco se conocen detalles de la estremec...
# ...                                                                             ...
# 0ac9dc5c1780ddb3720ed0b220bc03cc  La iluminacin de calles o la recoleccin de bas...
# b82d7a219f809ba37ea242d6cbb3ae3c  El nombre de Margarita Rosa de Francisco est g...
# 886e3e2c9db0b56f45183e5e1cfe64f3  En el Congreso volvi a aterrizar una iniciativ...
# 23b6232a093b0c11e25e9eaab73de2c9  Ayer en la maana, en los pasillos del Congreso...
# d1f33e8ba9d5ce1a1160cc6704fcc77b  James Rodrguez est viviendo momentos difciles ...
#
#                                                                               title  \
# uid
# 7da415dea9662ea9a86bb9511a97d018  La nueva pelcula de 'Terminator', un fracaso d...
# cf95bed3ca9731c52344be47f1c47828  Por qu James pasa por su peor momento desde su...
# 12101d7231ebe08b10c9960e43dc1d6f  Sony yMicrosoftse unen para desarrollar videoj...
# d1863696880af5764bb079c76eb5328c  As estn las cuentas en el Congreso para sacar ...
# a77b77e72c58bf6c4fb0ab16de9b4439  La nueva pelcula de 'Terminator', un fracaso d...
# ...                                                                             ...
# 0ac9dc5c1780ddb3720ed0b220bc03cc                      Educacin y Premios Nobel 2019
# b82d7a219f809ba37ea242d6cbb3ae3c                                                NaN
# 886e3e2c9db0b56f45183e5e1cfe64f3  Llmelo como quiera: Corte Constitucional acaba...
# 23b6232a093b0c11e25e9eaab73de2c9  "Bombardeo contra campamento de Gildardo Cucho...
# d1f33e8ba9d5ce1a1160cc6704fcc77b  "No es de Shannon": las revelaciones sobre el ...
#
#                                                                                 url  \
# uid
# 7da415dea9662ea9a86bb9511a97d018  https://www.semana.com//deportes/articulo/asi-...
# cf95bed3ca9731c52344be47f1c47828  https://www.semana.com//deportes/articulo/cham...
# 12101d7231ebe08b10c9960e43dc1d6f  https://www.semana.com//vida-moderna/articulo/...
# d1863696880af5764bb079c76eb5328c  https://www.semana.com//nacion/articulo/roy-ba...
# a77b77e72c58bf6c4fb0ab16de9b4439  https://www.semana.com//mundo/articulo/el-acto...
# ...                                                                             ...
# 0ac9dc5c1780ddb3720ed0b220bc03cc  https://www.dinero.com/pais/articulo/como-se-i...
# b82d7a219f809ba37ea242d6cbb3ae3c  https://www.semana.com//gente/articulo/margari...
# 886e3e2c9db0b56f45183e5e1cfe64f3  https://www.semana.com//nacion/articulo/radica...
# 23b6232a093b0c11e25e9eaab73de2c9  https://www.semana.com//nacion/articulo/mocion...
# d1f33e8ba9d5ce1a1160cc6704fcc77b  https://www.semana.com//deportes/articulo/por-...
#
#                                  newspaper_uid            host  \
# uid
# 7da415dea9662ea9a86bb9511a97d018        semana  www.semana.com
# cf95bed3ca9731c52344be47f1c47828        semana  www.semana.com
# 12101d7231ebe08b10c9960e43dc1d6f        semana  www.semana.com
# d1863696880af5764bb079c76eb5328c        semana  www.semana.com
# a77b77e72c58bf6c4fb0ab16de9b4439        semana  www.semana.com
# ...                                        ...             ...
# 0ac9dc5c1780ddb3720ed0b220bc03cc        semana  www.dinero.com
# b82d7a219f809ba37ea242d6cbb3ae3c        semana  www.semana.com
# 886e3e2c9db0b56f45183e5e1cfe64f3        semana  www.semana.com
# 23b6232a093b0c11e25e9eaab73de2c9        semana  www.semana.com
# d1f33e8ba9d5ce1a1160cc6704fcc77b        semana  www.semana.com
#
#                                   n_tokens_title  n_tokens_body
# uid
# 7da415dea9662ea9a86bb9511a97d018             5.0           13.0
# cf95bed3ca9731c52344be47f1c47828             8.0           34.0
# 12101d7231ebe08b10c9960e43dc1d6f             9.0           30.0
# d1863696880af5764bb079c76eb5328c             8.0           35.0
# a77b77e72c58bf6c4fb0ab16de9b4439             5.0           27.0
# ...                                          ...            ...
# 0ac9dc5c1780ddb3720ed0b220bc03cc             3.0           28.0
# b82d7a219f809ba37ea242d6cbb3ae3c             NaN            NaN
# 886e3e2c9db0b56f45183e5e1cfe64f3             8.0           36.0
# 23b6232a093b0c11e25e9eaab73de2c9             7.0           49.0
# d1f33e8ba9d5ce1a1160cc6704fcc77b             4.0           26.0
#
# [44 rows x 7 columns]
